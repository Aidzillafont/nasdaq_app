# %% [markdown]
# # How to
# First import and create an instance of your nasdaq data grabber object

# %%
from nasdaq_data import nasdaq_grabber as ng
my_ng = ng()

# %% [markdown]
# ## Get Top Stocks by Market Cap
# Call nasdaq_stocks and input the number of tickers you want and you will get info on stocks in order of Market Cap

# %%
my_ng.nasdaq_stocks(10)
# Out:
#   symbol                                               name    lastsale  \
# 0   AAPL                            Apple Inc. Common Stock     $150.43
# 1   MSFT                 Microsoft Corporation Common Stock     $237.92
# 2   GOOG                Alphabet Inc. Class C Capital Stock      $99.17
# 3  GOOGL                 Alphabet Inc. Class A Common Stock      $98.74
# 4   AMZN                      Amazon.com, Inc. Common Stock     $113.78
# 5   TSLA                           Tesla, Inc. Common Stock     $275.33
# 6  BRK/A                            Berkshire Hathaway Inc.  $404485.25
# 7  BRK/B                            Berkshire Hathaway Inc.     $267.77
# 8    UNH  UnitedHealth Group Incorporated Common Stock (DE)     $513.61
# 9    JNJ                     Johnson & Johnson Common Stock     $166.72
#
#   netchange pctchange          marketCap                            url
# 0     -2.31   -1.512%  2,608,056,056,200   /market-activity/stocks/aapl
# 1     -3.06    -1.27%  1,774,381,634,186   /market-activity/stocks/msft
# 2     -1.40   -1.392%  1,293,573,480,000   /market-activity/stocks/goog
# 3     -1.40   -1.398%  1,287,964,560,000  /market-activity/stocks/googl
# 4     -3.53   -3.009%  1,157,926,339,396   /market-activity/stocks/amzn
# 5    -13.26   -4.595%    862,738,307,490   /market-activity/stocks/tsla
# 6   -889.76   -0.219%    594,946,837,609  /market-activity/stocks/brk/a
# 7     -0.74   -0.276%    590,783,995,813  /market-activity/stocks/brk/b
# 8     -3.85   -0.744%    480,421,913,683    /market-activity/stocks/unh
# 9      0.54    0.325%    438,336,872,094    /market-activity/stocks/jnj

# %% [markdown]
# ## Get Historical Prices
# Pass a start date and end date in ISO format along with your ticker to nasdaq_historical_price to get historical prices

# %%
from dateutil.relativedelta import relativedelta
import time
import datetime as dt

#today
t = dt.date.today().replace(day=1)
#one year ago
t0 = t - relativedelta(years=1)

#isoformat
iso_t0, iso_t = t0.isoformat(), t.isoformat()

my_ng.nasdaq_historical_price('AAPL', iso_t0, iso_t)
# Out:
#            date    close      volume      open     high       low
# 0    09/01/2022  $157.96  74,229,900   $156.64  $158.42   $154.67
# 1    08/31/2022  $157.22  87,991,090  $160.305  $160.58   $157.14
# 2    08/30/2022  $158.91  77,906,200   $162.13  $162.56   $157.72
# 3    08/29/2022  $161.38  73,313,950  $161.145   $162.9   $159.82
# 4    08/26/2022  $163.62  78,960,980   $170.57  $171.05   $163.56
# ..          ...      ...         ...       ...      ...       ...
# 248  09/08/2021  $155.11  74,420,210   $156.98  $157.04  $153.975
# 249  09/07/2021  $156.69  82,278,260   $154.97  $157.26   $154.39
# 250  09/03/2021   $154.3  57,866,070   $153.76  $154.63   $153.09
# 251  09/02/2021  $153.65  71,171,320   $153.87  $154.72    $152.4
# 252  09/01/2021  $152.51  80,313,710   $152.83  $154.98   $152.34
#
# [253 rows x 6 columns]

# %% [markdown]
# ## Get Stocks Financal Data
# Call nasdaq_financals and pass in a frequency you desire
# 1. Annual
# 2. Semi Annual

# %%
my_ng.nasdaq_financals('AAPL', 1)
# Out:
#   symbol tabs.incomeStatementTable tabs.balanceSheetTable tabs.cashFlowTable  \
# 0   AAPL          Income Statement          Balance Sheet          Cash Flow
#
#   tabs.financialRatiosTable incomeStatementTable.headers.value1  \
# 0          Financial Ratios                      Period Ending:
#
#   incomeStatementTable.headers.value2 incomeStatementTable.headers.value3  \
# 0                           9/25/2021                           9/26/2020
#
#   incomeStatementTable.headers.value4 incomeStatementTable.headers.value5  \
# 0                           9/28/2019                           9/29/2018
#
#    ... cashFlowTable.headers.value3 cashFlowTable.headers.value4  \
# 0  ...                    9/26/2020                    9/28/2019
#
#   cashFlowTable.headers.value5  \
# 0                    9/29/2018
#
#                                   cashFlowTable.rows  \
# 0  [{'value1': 'Net Income', 'value2': '$94,680,0...
#
#   financialRatiosTable.headers.value1 financialRatiosTable.headers.value2  \
# 0                      Period Ending:                           9/25/2021
#
#   financialRatiosTable.headers.value3 financialRatiosTable.headers.value4  \
# 0                           9/26/2020                           9/28/2019
#
#   financialRatiosTable.headers.value5  \
# 0                           9/29/2018
#
#                            financialRatiosTable.rows
# 0  [{'value1': 'Liquidity Ratios', 'value2': '', ...
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Get Other Data
#
# Calling the nasdaq_data function and supplying type to any of the numbers below will get you
#
# 1. Analyst Target Price and Ratings
# 2. PEG Ratio
# 3. Momentum Estimate
# 4. Earnings Forecast
# 5. Earnings Surprise
# 6. EPS

# %%
#analysts ratings
my_ng.nasdaq_data('AAPL',1)
# Out:
#   symbol                                historicalConsensus  \
# 0   aapl  [{'z': {'buy': 19, 'hold': 5, 'sell': 0, 'date...
#
#    consensusOverview.lowPriceTarget  consensusOverview.highPriceTarget  \
# 0                             136.0                              220.0
#
#    consensusOverview.priceTarget  consensusOverview.buy  \
# 0                         183.45                     23
#
#    consensusOverview.sell  consensusOverview.hold
# 0                       1                       4

# %%
#PEG Ratio
my_ng.nasdaq_data('AAPL',2)
# Out:
#                             pegr.label  \
# 0  Forecast 12 Month Forward PEG Ratio
#
#                                            pegr.text  pegr.pegValue  \
# 0  Investors are always looking for companies wit...           1.95
#
#                                     per.peRatioChart             per.label  \
# 0  [{'x': '2021 Actual', 'y': 26.81}, {'x': '2022...  Price/Earnings Ratio
#
#                                             per.text  \
# 0  Price/Earnings Ratio is a widely used stock ev...
#
#                                   per.dataProvider  \
# 0  <b>Data Provider:</b> Zacks Investment Research
#
#                                     gr.peGrowthChart  \
# 0  [{'z': 'Growth', 'x': '2022', 'y': 8.8}, {'z':...
#
#                     gr.title
# 0  Forecast P/E Growth Rates
